# %% [markdown]
# # Chapter 8 — Exercises## RL for HPO & AutoML

# %% [markdown]
# ### Exercise 8.1: Bayesian Optimization baselineImplement Gaussian Process-based Bayesian Optimization as a baseline. Compare with the REINFORCE HPO agent on 50 evaluations. Which finds better hyperparameters? Which is more sample-efficient?

# %%
# Exercise 8.1: GP-based Bayesian Optimization

# %% [markdown]
# ### Exercise 8.2: Successive HalvingImplement Successive Halving: run all hyperparameter configurations for a small budget, keep the top half, run those for double the budget, repeat. Compare against Hyperband.

# %%
# Exercise 8.2: Successive Halving

# %% [markdown]
# ### Exercise 8.3: Multi-fidelity RL HPOModify the HPO environment to use low-fidelity evaluations (1-fold CV, 50% of data) for exploration and high-fidelity (5-fold CV, full data) for exploitation. Design a reward that accounts for evaluation cost.

# %%
# Exercise 8.3
