# %% [markdown]
# # Chapter 5 — Exercises## Q-Learning and DQN

# %% [markdown]
# ### Exercise 5.1: Implement experience replay from scratchImplement a `ReplayBuffer` class with `push()` and `sample()` methods. Verify that sampling is:- Random (not sequential)- Uniform (each transition equally likely)- Efficient (O(1) sampling, O(1) insertion)

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        pass  # TODO
    def push(self, state, action, reward, next_state, done):
        pass  # TODO
    def sample(self, batch_size):
        pass  # TODO
    def __len__(self):
        pass  # TODO

# %% [markdown]
# ### Exercise 5.2: Compare ε-decay strategiesTrain the tabular Q-Learning agent from the concept notebook with three ε decay strategies:1. Linear decay: ε = 1.0 - episode/n_episodes2. Exponential decay: ε = 0.99^episode (as in concept notebook)3. Constant ε = 0.1 throughoutPlot all three learning curves. Which converges fastest? Which achieves the highest final performance?

# %%
# Exercise 5.2
import numpy as np, random
from collections import defaultdict

# %% [markdown]
# ### Exercise 5.3: Understand Double DQNIn standard DQN, the target is `r + γ max_{a'} Q_target(s', a')`. This overestimates Q values.Double DQN uses: `r + γ Q_target(s', argmax_{a'} Q_online(s', a'))`Implement Double DQN by changing two lines of the training loop. Does it improve performance on CartPole?

# %%
# Exercise 5.3: Double DQN modification
# Hint: only 2 lines change in the training loop
