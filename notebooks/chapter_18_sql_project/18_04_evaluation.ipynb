# %% [markdown]
# # Chapter 18 — SQL Project: Step 4## Evaluation: Before and After[![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com)**See Chapter 18, Section 18.5 for the complete annotated code.**Run this notebook after completing `18_03_*.ipynb`

# %%
# Chapter 18, Step 4: Evaluation: Before and After
# See book section 18.5 for the full implementation.
# This notebook runs the code from that section.
import torch
print(f'GPU available: {torch.cuda.is_available()}')
