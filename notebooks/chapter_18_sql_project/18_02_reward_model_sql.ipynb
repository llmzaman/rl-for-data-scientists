# %% [markdown]
# # Chapter 18 — SQL Project: Step 2## Reward Model for SQL Quality[![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com)**See Chapter 18, Section 18.3 for the complete annotated code.**Run this notebook after completing `18_01_*.ipynb`

# %%
# Chapter 18, Step 2: Reward Model for SQL Quality# See book section 18.3 for the full implementation.# This notebook runs the code from that section.import torchprint(f'GPU available: {torch.cuda.is_available()}')
