# %% [markdown]
# # Chapter 6 — Exercises## Policy Gradients, PPO & DPO

# %% [markdown]
# ### Exercise 6.1: Implement REINFORCE with baselineThe baseline reduces variance without introducing bias. Implement REINFORCE where the baseline b = mean(G_t) is subtracted from each return:∇J(θ) = E[∇ log π(a|s) · (G_t - b)]

# %%
# Exercise 6.1
import torch, torch.nn as nn

# %% [markdown]
# ### Exercise 6.2: GAE with different λ valuesFor a fixed set of rewards/values (generate synthetically), compute GAE advantages with λ ∈ {0, 0.5, 0.95, 1.0}. Plot the distribution of advantages for each λ. Which has the highest variance? Which has the most bias?

# %%
# Exercise 6.2
import torch, numpy as np

# %% [markdown]
# ### Exercise 6.3: DPO loss sensitivityPlot the DPO loss as a function of the log-ratio margin (chosen_logratios - rejected_logratios) for β ∈ {0.05, 0.1, 0.5}.- What is the gradient of the DPO loss at zero margin?- What happens at very large margins?- Why is this analogous to the saturation problem in binary cross-entropy?

# %%
# Exercise 6.3
import torch
