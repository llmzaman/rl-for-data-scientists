# %% [markdown]
# # Chapter 10 — Exercises## LLM Agents

# %% [markdown]
# ### Exercise 10.1: Add a web search toolAdd a `search_web(query)` tool that returns the top result from DuckDuckGo (using the `duckduckgo-search` library). Run 5 questions that require factual lookup. Measure accuracy with vs. without the tool.

# %%
# Exercise 10.1
# pip install duckduckgo-search

# %% [markdown]
# ### Exercise 10.2: Agent failure mode analysisCreate 10 prompts specifically designed to trigger each of the 5 agent failure modes from Chapter 10:- Action-outcome mismatch, no error recovery, sycophancy, long-horizon breakdown, tool generalisationDocument which prompts trigger which failure modes.

# %%
# Exercise 10.2: Failure mode taxonomy
failure_examples = {
    'action_outcome_mismatch': None,   # TODO
    'no_error_recovery': None,          # TODO
    'sycophancy': None,                 # TODO
    'long_horizon_breakdown': None,     # TODO
    'tool_generalisation': None,        # TODO
}

# %% [markdown]
# ### Exercise 10.3: Count the agency levelFor each of these systems, determine its agency level (L0-L5 from the spectrum in Chapter 10) and justify your answer:1. GPT-4 with no tools2. Claude with web search only3. Devin (coding agent)4. A thermostat5. AutoGPT with email + calendar + browser

# %%
# Exercise 10.3: Agency level classification
