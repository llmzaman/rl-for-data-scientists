# %% [markdown]
# # Chapter 9 — Exercises## Bandits & Offline RL

# %% [markdown]
# ### Exercise 9.1: Contextual bandit with LinUCBExtend the bandit environment so that each arm's reward depends on a 5-dimensional context vector. Implement LinUCB and verify it outperforms a context-blind UCB1.

# %%
# Exercise 9.1: LinUCB
import numpy as np

# %% [markdown]
# ### Exercise 9.2: The exploration-exploitation Goldilocks zoneFor ε-greedy, plot final 100-step average reward as a function of ε ∈ {0.001, 0.01, 0.05, 0.1, 0.2, 0.5, 1.0}. Find the optimal ε. Does the optimal ε depend on the number of arms? On the reward variance?

# %%
# Exercise 9.2

# %% [markdown]
# ### Exercise 9.3: Offline evaluation with inverse propensity scoringYou have logged data from a production ε-greedy recommender. Estimate the value of a new Thompson Sampling policy using inverse propensity scoring (IPS). Compare to the on-policy estimate.

# %%
# Exercise 9.3: Offline policy evaluation with IPS
