# %% [markdown]
# # Chapter 7 — Exercises## RL for Recommendation Systems

# %% [markdown]
# ### Exercise 7.1: Slate-based recommendationsModify the environment so the agent recommends **3 genres simultaneously** (a slate) rather than one at a time. How does the action space size change? How does DQN need to be modified?

# %%
# Exercise 7.1: Slate recommender
# Hint: the action space is now C(10,3) = 120 slates

# %% [markdown]
# ### Exercise 7.2: Long-term vs short-term rewardRun the DQN with γ=0.5 (shortsighted) vs γ=0.99 (far-sighted). Which learns to build user engagement over the session vs just maximising the next click?

# %%
# Exercise 7.2

# %% [markdown]
# ### Exercise 7.3: Thompson Sampling as a recommender baselineImplement Thompson Sampling for recommendations (each genre has a Beta(α,β) distribution updated by watch/skip feedback). Compare against DQN. When does Thompson Sampling outperform DQN?

# %%
# Exercise 7.3
